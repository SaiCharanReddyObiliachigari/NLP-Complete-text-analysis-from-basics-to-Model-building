# %% [markdown]
# <center><u><H1>Bag of Words</H1></u></center>

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer()

# %%
text1 = open('../Data/carl_sagan_quote4.txt').read()
text2 = open('../Data/carl_sagan_quote2.txt').read()
text3 = open('../Data/carl_sagan_quote3.txt').read()

# %%
corpus = [text1,text2,text3]

# %%
doc_vec = vectorizer.fit_transform(corpus)

# %%
df = pd.DataFrame(doc_vec.toarray().transpose(), index=vectorizer.get_feature_names())

# %%
# making a Term document matrix
df.columns = ['CS_text1','CS_text2','CS_text3']
df
# Out:
#               CS_text1  CS_text2  CS_text3
# almost               0         1         0
# also                 0         1         0
# and                  1         2         0
# another              0         0         1
# arranged             1         1         0
# away                 0         1         0
# billion              0         0         1
# blow                 0         1         0
# but                  0         1         0
# civilization         1         0         0
# combustible          0         1         0
# cosmic               0         0         1
# crucial              1         0         0
# depend               1         0         0
# disagrees            0         0         1
# disaster             0         1         0
# elements             1         0         0
# every                0         0         1
# faces                0         1         0
# find                 0         0         1
# for                  0         2         0
# galaxies             0         0         1
# get                  0         1         0
# going                0         1         0
# have                 0         1         0
# him                  0         0         1
# human                0         0         1
# hundred              0         0         1
# if                   0         0         1
# ignorance            0         1         0
# ...                ...       ...       ...
# not                  0         0         1
# of                   0         1         1
# on                   1         0         0
# one                  0         1         1
# or                   0         1         0
# our                  0         1         0
# perspective          0         0         1
# power                0         1         0
# precious             0         0         1
# prescription         0         1         0
# profoundly           1         0         0
# science              1         1         0
# so                   0         1         0
# sooner               0         1         0
# technology           1         1         0
# that                 0         1         0
# the                  0         0         1
# things               0         1         0
# this                 0         2         0
# to                   0         1         0
# understands          0         1         0
# up                   0         1         0
# us                   0         0         1
# ve                   1         0         0
# we                   1         2         0
# which                1         0         0
# while                0         1         0
# will                 0         0         1
# with                 0         1         1
# you                  0         0         2
#
# [70 rows x 3 columns]

# %% [markdown]
# ## Term Frequency-Inverse Document Frequency(TF-IDF)

# %% [markdown]
# ### TF-IDF is a statistical measure to reflect the relevance of the term to the document in a collection of documents or corpus.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
doc_vec = vectorizer.fit_transform(corpus)

# %%
df = pd.DataFrame(doc_vec.toarray().transpose(), index=vectorizer.get_feature_names())
df.columns =  ['CS_text1','CS_text2','CS_text3']
df
# Out:
#               CS_text1  CS_text2  CS_text3
# almost        0.000000  0.144700  0.000000
# also          0.000000  0.144700  0.000000
# and           0.217375  0.220096  0.000000
# another       0.000000  0.000000  0.193496
# arranged      0.217375  0.110048  0.000000
# away          0.000000  0.144700  0.000000
# billion       0.000000  0.000000  0.193496
# blow          0.000000  0.144700  0.000000
# but           0.000000  0.144700  0.000000
# civilization  0.285821  0.000000  0.000000
# combustible   0.000000  0.144700  0.000000
# cosmic        0.000000  0.000000  0.193496
# crucial       0.285821  0.000000  0.000000
# depend        0.285821  0.000000  0.000000
# disagrees     0.000000  0.000000  0.193496
# disaster      0.000000  0.144700  0.000000
# elements      0.285821  0.000000  0.000000
# every         0.000000  0.000000  0.193496
# faces         0.000000  0.144700  0.000000
# find          0.000000  0.000000  0.193496
# for           0.000000  0.289399  0.000000
# galaxies      0.000000  0.000000  0.193496
# get           0.000000  0.144700  0.000000
# going         0.000000  0.144700  0.000000
# have          0.000000  0.144700  0.000000
# him           0.000000  0.000000  0.193496
# human         0.000000  0.000000  0.193496
# hundred       0.000000  0.000000  0.193496
# if            0.000000  0.000000  0.193496
# ignorance     0.000000  0.144700  0.000000
# ...                ...       ...       ...
# not           0.000000  0.000000  0.193496
# of            0.000000  0.110048  0.147159
# on            0.285821  0.000000  0.000000
# one           0.000000  0.110048  0.147159
# or            0.000000  0.144700  0.000000
# our           0.000000  0.144700  0.000000
# perspective   0.000000  0.000000  0.193496
# power         0.000000  0.144700  0.000000
# precious      0.000000  0.000000  0.193496
# prescription  0.000000  0.144700  0.000000
# profoundly    0.285821  0.000000  0.000000
# science       0.217375  0.110048  0.000000
# so            0.000000  0.144700  0.000000
# sooner        0.000000  0.144700  0.000000
# technology    0.217375  0.110048  0.000000
# that          0.000000  0.144700  0.000000
# the           0.000000  0.000000  0.193496
# things        0.000000  0.144700  0.000000
# this          0.000000  0.289399  0.000000
# to            0.000000  0.144700  0.000000
# understands   0.000000  0.144700  0.000000
# up            0.000000  0.144700  0.000000
# us            0.000000  0.000000  0.193496
# ve            0.285821  0.000000  0.000000
# we            0.217375  0.220096  0.000000
# which         0.285821  0.000000  0.000000
# while         0.000000  0.144700  0.000000
# will          0.000000  0.000000  0.193496
# with          0.000000  0.110048  0.147159
# you           0.000000  0.000000  0.386992
#
# [70 rows x 3 columns]

# %% [markdown]
# ## Reference:
#
# http://scikit-learn.org/stable/modules/feature_extraction.html
